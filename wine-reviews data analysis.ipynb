# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 读取winemag_data_first150k表中的数据

# %%
winemag_data_first150k = pd.read_csv("wine-reviews/winemag-data_first150k.csv",index_col=0)

# %% [markdown]
# ### 数据总览

# %% [markdown]
# country:这个葡萄酒来自哪个国家

# %% [markdown]
# description:对于这个葡萄酒的描述

# %% [markdown]
# designation:酒厂中的葡萄园

# %% [markdown]
# points:对葡萄酒的评分

# %% [markdown]
# price:酒的价格

# %% [markdown]
# province:葡萄酒产于哪个的省/州

# %% [markdown]
# region_1:生产葡萄酒的省/州

# %% [markdown]
# region_2:生产葡萄酒更加特定的区域

# %% [markdown]
# variety:酿造葡萄酒的葡萄种类

# %% [markdown]
# winery:酿酒厂

# %%
winemag_data_first150k = winemag_data_first150k.drop(columns=['description'],axis=1)
winemag_data_first150k
# Out:
#        country                           designation  points  price  \
# 0           US                     Martha's Vineyard      96  235.0
# 1        Spain  Carodorum Selección Especial Reserva      96  110.0
# 2           US         Special Selected Late Harvest      96   90.0
# 3           US                               Reserve      96   65.0
# 4       France                            La Brûlade      95   66.0
# ...        ...                                   ...     ...    ...
# 150925   Italy                                   NaN      91   20.0
# 150926  France                        Cuvée Prestige      91   27.0
# 150927   Italy                         Terre di Dora      91   20.0
# 150928  France                       Grand Brut Rosé      90   52.0
# 150929   Italy                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 9 columns]

# %% [markdown]
# ### 标称属性频数统计

# %%
#country统计
data_country = winemag_data_first150k.iloc[:,0]

# %%
#进行频数统计
data_country_count = data_country.value_counts()
data_country_count
# Out:
# US                        62397
# Italy                     23478
# France                    21098
# Spain                      8268
# Chile                      5816
# Argentina                  5631
# Portugal                   5322
# Australia                  4957
# New Zealand                3320
# Austria                    3057
# Germany                    2452
# South Africa               2258
# Greece                      884
# Israel                      630
# Hungary                     231
# Canada                      196
# Romania                     139
# Slovenia                     94
# Uruguay                      92
# Croatia                      89
# Bulgaria                     77
# Moldova                      71
# Mexico                       63
# Turkey                       52
# Georgia                      43
# Lebanon                      37
# Cyprus                       31
# Brazil                       25
# Macedonia                    16
# Serbia                       14
# Morocco                      12
# England                       9
# Luxembourg                    9
# Lithuania                     8
# India                         8
# Czech Republic                6
# Ukraine                       5
# South Korea                   4
# Switzerland                   4
# Bosnia and Herzegovina        4
# Slovakia                      3
# China                         3
# Egypt                         3
# Albania                       2
# Montenegro                    2
# Japan                         2
# Tunisia                       2
# US-France                     1
# Name: country, dtype: int64

# %%
#统计出现频率前15的数据,并可视化
data_country_count.head(15).plot.bar()

# %%
#designation统计
data_designation = winemag_data_first150k.iloc[:,1].dropna()
#进行频数统计
designation_count = data_designation.value_counts()
print(designation_count)
#统计出现频率前15的数据,并可视化
designation_count.head(15).plot.bar()
# Out:
# Reserve                 2752
# Reserva                 1810
# Estate                  1571
# Barrel sample           1326
# Riserva                  754
#                         ...
# Cupatge d'Honor Brut       1
# Springview                 1
# Grains Dorés               1
# Reserva del Virrey         1
# In The Rocks               1
# Name: designation, Length: 30621, dtype: int64

# %%
#province统计
data_province = winemag_data_first150k.iloc[:,4].dropna()
#进行频数统计
province_count = data_province.value_counts()
print(province_count)
#统计出现频率前15的数据,并可视化
province_count.head(15).plot.bar()
# Out:
# California          44508
# Washington           9750
# Tuscany              7281
# Bordeaux             6111
# Northern Spain       4892
#                     ...
# Slovenska Istra         1
# Serra do Sudeste        1
# Central Greece          1
# Valais                  1
# Cape South Coast        1
# Name: province, Length: 455, dtype: int64

# %%
#region_1统计
data_region_1 = winemag_data_first150k.iloc[:,5].dropna()
#进行频数统计
region_1_count = data_region_1.value_counts()
print(region_1_count)
#统计出现频率前15的数据,并可视化
region_1_count.head(15).plot.bar()
# Out:
# Napa Valley                                6209
# Columbia Valley (WA)                       4975
# Mendoza                                    3586
# Russian River Valley                       3571
# California                                 3462
#                                            ...
# Vin de Pays des Sables du Golfe du Lion       1
# Ventura County                                1
# Vin de Pays de Sainte-Marie la Blanche        1
# Loazzolo                                      1
# Rosso di Cerignola                            1
# Name: region_1, Length: 1236, dtype: int64

# %%
#region_2统计
data_region_2 = winemag_data_first150k.iloc[:,6].dropna()
#进行频数统计
region_2_count = data_region_2.value_counts()
print(region_2_count)
#数据可视化
region_2_count.plot.bar()
# Out:
# Central Coast              13057
# Sonoma                     11258
# Columbia Valley             9157
# Napa                        8801
# California Other            3516
# Willamette Valley           3181
# Mendocino/Lake Counties     2389
# Sierra Foothills            1660
# Napa-Sonoma                 1645
# Finger Lakes                1510
# Central Valley              1115
# Long Island                  771
# Southern Oregon              662
# Oregon Other                 661
# North Coast                  632
# Washington Other             593
# South Coast                  198
# New York Other               147
# Name: region_2, dtype: int64

# %%
#variety统计
data_variety = winemag_data_first150k.iloc[:,7].dropna()
#进行频数统计
variety_count = data_variety.value_counts()
print(variety_count)
#统计出现频率前20的数据,并可视化
variety_count.head(20).plot.bar()
# Out:
# Chardonnay                  14482
# Pinot Noir                  14291
# Cabernet Sauvignon          12800
# Red Blend                   10062
# Bordeaux-style Red Blend     7347
#                             ...
# Xynisteri                       1
# Carignan-Syrah                  1
# Sauvignon Musqué                1
# Sacy                            1
# Muskat                          1
# Name: variety, Length: 632, dtype: int64

# %%
#winery统计
data_winery = winemag_data_first150k.iloc[:,8].dropna()
#进行频数统计
winery_count = data_winery.value_counts()
print(winery_count)
#统计出现频率前30的数据,并可视化
winery_count.head(30).plot.bar(figsize=(30,10))
# Out:
# Williams Selyem           374
# Testarossa                274
# DFJ Vinhos                258
# Chateau Ste. Michelle     225
# Columbia Crest            217
#                          ...
# Château de Brague           1
# Parcel 41                   1
# Domaine Damien Lorieux      1
# Rapido                      1
# Valerie Hill                1
# Name: winery, Length: 14810, dtype: int64

# %% [markdown]
# ### 数值属性

# %% [markdown]
# #### 数值属性的数据概括

# %%
data_describe = winemag_data_first150k.describe()
data_describe
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %% [markdown]
# #### 五数概括

# %% [markdown]
# points：
#     - 最小值：80
#     - 最大值：100
#     - 四分位数（Q1）：86
#     - 中位数：88
#     - 四分位数（Q3）：90
# price：
#     - 最小值：4
#     - 最大值：2300
#     - 四分位数（Q1）：16
#     - 中位数：24
#     - 四分位数（Q3）：40

# %% [markdown]
# #### 缺失值统计

# %%
data_points = winemag_data_first150k.iloc[:,2]
data_price = winemag_data_first150k.iloc[:,3]
print("points missing value:",data_points.isnull().sum())
print("price missing value:",data_price.isnull().sum())
# Out:
# points missing value: 0
# price missing value: 13695

# %% [markdown]
# ### 数据可视化

# %% [markdown]
# #### 绘制直方图

# %%
#绘制points直方图
data_points.hist(xlabelsize=20,ylabelsize=20,figsize=(30,10),density=True)

# %%
#绘制price直方图
data_price.dropna().hist(xlabelsize=20,ylabelsize=20,figsize=(30,10),density=True)

# %%
#由上图可知,价格大概分布在0-250之间,因此主要绘制价格<250的数据
data_price_litter = data_price.dropna()[data_price < 250]
data_price_litter.hist(xlabelsize=20,ylabelsize=20,figsize=(30,10),bins=100,density=True)

# %% [markdown]
# #### 绘制盒图

# %%
# %matplotlib inline

#解决中文乱码问题!
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
#points盒图绘制
figure,ax = plt.subplots(nrows=1,ncols=1,figsize=(30,10),dpi=100)
ax.boxplot(data_points.dropna(),notch=False,vert=True)
ax.tick_params(labelsize=23)
ax.set_title('points 盒图',fontsize=23)
plt.show()

# %%
#绘制price盒图
figure,ax = plt.subplots(nrows=1,ncols=1,figsize=(30,10),dpi=100)
ax.boxplot(data_price_litter,notch=False,vert=True)
ax.tick_params(labelsize=23)
ax.set_title('points 盒图',fontsize=23)
plt.show()

# %% [markdown]
# ## 处理缺失值

# %% [markdown]
# ### 将缺失部分剔除

# %%
data_price_delete = data_price.dropna()
data_price_delete[data_price_delete<500].hist(xlabelsize=20,ylabelsize=20,figsize=(30,10),bins=200,density=True)
figure,ax = plt.subplots(nrows=1,ncols=1,figsize=(30,10),dpi=100)
ax.boxplot(data_price_delete[data_price_delete<500],notch=False,vert=True)
ax.tick_params(labelsize=23)
ax.set_title('points 盒图(缺失处理)',fontsize=23)
plt.show()

# %% [markdown]
# ### 用最高频率值来填补缺失值

# %%
temp = data_price.mode()[0]
data_price_most = data_price.fillna(temp)
data_price_most[data_price_most<500].hist(xlabelsize=20,ylabelsize=20,figsize=(30,10),bins=200,density=True)
figure,ax = plt.subplots(nrows=1,ncols=1,figsize=(30,10),dpi=100)
ax.boxplot(data_price_most[data_price_most<500],notch=False,vert=True)
ax.tick_params(labelsize=23)
ax.set_title('price 盒图(最高频率填补)',fontsize=23)
plt.show()

# %% [markdown]
# ### 通过属性的相关关系来填补缺失值

# %%
data_region_1_relation = winemag_data_first150k.iloc[:,5]
data_province_list = winemag_data_first150k.iloc[:,4]
for i in data_region_1_relation.index:
    if data_region_1_relation.loc[i] is np.nan:
        data_region_1_relation.loc[i] = data_province_list.loc[i]
data_region_1_relation.value_counts().head(15).plot.bar()

# %% [markdown]
# ### 通过数据对象之间的相似性来填补缺失值

# %%
pricetemp = {}
data_points_temp = winemag_data_first150k.iloc[:,2]
data_price_temp = winemag_data_first150k.iloc[:,3]
for i in data_points_temp.index:
    if np.isnan(data_price_temp[i]) == False:
        if data_points_temp[i] in pricetemp:
            pricetemp[data_points_temp[i]].append(data_price_temp[i])
        else :
            pricetemp[data_points_temp[i]] = [data_price_temp[i]]
for key,value in pricetemp.items():
    pricetemp[key] = np.mean(value)

# %%
data_price = winemag_data_first150k.iloc[:,3]
for i in data_price.index:
    if np.isnan(data_price[i]) == True:
        data_price[i] = pricetemp[data_points_temp[i]]

# %%
# %matplotlib inline

#解决中文乱码问题!
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
data_price[data_price<500].hist(xlabelsize=20,ylabelsize=20,figsize=(30,10),bins=200,density=True)
figure,ax = plt.subplots(nrows=1,ncols=1,figsize=(30,10),dpi=100)
ax.boxplot(data_price[data_price<500],notch=False,vert=True)
ax.tick_params(labelsize=23)
ax.set_title('price 盒图(通过数据对象之间的相似性来填补)',fontsize=23)
plt.show()
